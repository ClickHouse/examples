# %% [markdown]
# # How to build an AI Agent with LlamaIndex and ClickHouse MCP Server
#
# In this notebook we'll see how to build a [LlamaIndex](https://github.com/run-llama/llama_index)  AI agent that can interact with [ClickHouse's SQL playground](https://sql.clickhouse.com/).

# %% [markdown]
# ## Install libraries
# We need to install LlamaIndex, the ClickHouse connector library, and Anthropic, as we'll be using that as our LLM.

# %%
# !pip install -q --upgrade pip

# %%
# !pip install -q llama-index
# !pip install -q clickhouse-connect
# !pip install -q llama-index-llms-anthropic
# !pip install -q llama-index-tools-mcp

# %% [markdown]
# ## Setup credentials
# Let's provide our Anthropic API key.

# %%
import getpass
import os

# %%
os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter Anthropic API Key:")
# Out:
# Enter Anthropic API Key: ········

# %% [markdown]
# ## Initialize LLM
# And then initialize the Claude Sonnet 4.0 model.

# %%
from llama_index.llms.anthropic import Anthropic

# %%
llm = Anthropic(model="claude-sonnet-4-0")

# %% [markdown]
# ## Configure MCP client
# Next, we're going to create an MCP client that connects to the ClickHouse SQL Playground via the  ClickHouse MCP server.

# %% [markdown]
# We then need to convert those from Python functions into Llama Index tools:

# %%
from llama_index.tools.mcp import BasicMCPClient, McpToolSpec

# %%
mcp_client = BasicMCPClient(
    "uv", 
    args=[
        "run", 
        "--with", "mcp-clickhouse",
        "--python", "3.13", 
        "mcp-clickhouse"
    ],
    env={
        "CLICKHOUSE_HOST": "sql-clickhouse.clickhouse.com",
        "CLICKHOUSE_PORT": "8443",
        "CLICKHOUSE_USER": "demo",
        "CLICKHOUSE_PASSWORD": "",
        "CLICKHOUSE_SECURE": "true"
    } 
)

mcp_tool_spec = McpToolSpec(
    client=mcp_client,
)

# %%
tools = await mcp_tool_spec.to_tool_list_async()

# %% [markdown]
# ## Creating Agent
# Now we're ready to create an agent that has access to those tools. We're going to set the maximum number of tool calls in one run to 10, but you can modify that if you want.

# %%
from llama_index.core.agent import AgentRunner, FunctionCallingAgentWorker

# %%
agent_worker = FunctionCallingAgentWorker.from_tools(
    tools=tools, 
    llm=llm, verbose=True, max_function_calls=10
)
agent = AgentRunner(agent_worker)

# %% [markdown]
# ## Running the agent
# Finally, we can ask the agent a question:

# %%
response = agent.query("What's the most popular repository?")
# Out:
# Added user message to memory: What's the most popular repository?
# === LLM Response ===
# I'll help you find the most popular repository. Let me first explore the available databases and tables to understand the data structure.
# === Calling Function ===
# Calling function: list_databases with args: {}
# === Function Output ===
# meta=None content=[TextContent(type='text', text='amazon\nbluesky\ncountry\ncovid\ndefault\ndns\nenvironmental\nfood\nforex\ngeo\ngit\ngithub\nhackernews\nimdb\nlogs\nmetrica\nmgbench\nmta\nnoaa\nnyc_taxi\nnypd\nontime\nopensky\notel\notel_v2\npypi\nrandom\nreddit\nrubygems\nstackoverflow\nstar_schema\nstock\nsystem\ntw_weather\ntwitter\nuk\nwiki\nwords\nyoutube', annotations=None)] isError=False
# === LLM Response ===
# I can see there's a `github` database which likely contains repository data. Let me explore the tables in that database.
# === Calling Function ===
# Calling function: list_tables with args: {"database": "github"}
# === Function Output ===
# meta=None content=[TextContent(type='text', text='{\n  "database": "github",\n  "name": "actors_per_repo",\n  "comment": "",\n  "columns": [\n    {\n      "name": "actor_login",\n      "type": "LowCardinality(String)",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "repo_name",\n      "type": "String",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "pushes",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "issues",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "stars",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    }\n  ],\n  "create_table_query": "CREATE TABLE github.actors_per_repo\\\\n(\\\\n    `actor_login` LowCardinality(String),\\\\n    `repo_name` String,\\\\n    `pushes` UInt32,\\\\n    `issues` UInt32,\\\\n    `stars` UInt32,\\\\n    PROJECTION actor_login_order\\\\n    (\\\\n        SELECT *\\\\n        ORDER BY actor_login\\\\n    )\\\\n)\\\\nENGINE = SharedSummingMergeTree(\\\\\'/clickhouse/tables/{uuid}/{shard}\\\\\', \\\\\'{replica}\\\\\')\\\\nORDER BY (repo_name, actor_login)\\\\nSETTINGS index_granularity = 8192, deduplicate_merge_projection_mode = \\\\\'rebuild\\\\\'",\n  "row_count": 844967107,\n  "column_count": 5\n}', annotations=None), TextContent(type='text', text='{\n  "database": "github",\n  "name": "actors_per_repo_mv",\n  "comment": "",\n  "columns": [\n    {\n      "name": "actor_login",\n      "type": "LowCardinality(String)",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "repo_name",\n      "type": "String",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "pushes",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "issues",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    },\n    {\n      "name": "stars",\n      "type": "UInt32",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n    }\n  ],\n  "create_table_query": "CREATE MATERIALIZED VIEW github.actors_per_repo_mv TO github.actors_per_repo\\\\n(\\\\n    `actor_login` LowCardinality(String),\\\\n    `repo_name` String,\\\\n    `pushes` UInt32,\\\\n    `issues` UInt32,\\\\n    `stars` UInt32\\\\n)\\\\nAS SELECT\\\\n    actor_login,\\\\n    repo_name,\\\\n    countIf(event_type = \\\\\'PushEvent\\\\\') AS pushes,\\\\n    countIf(event_type = \\\\\'IssuesEvent\\\\\') AS issues,\\\\n    countIf(event_type = \\\\\'WatchEvent\\\\\') AS stars\\\\nFROM github.events\\\\nGROUP BY\\\\n    actor_login,\\\\n    repo_name",\n  "row_count": 844967107,\n  "column_count": 5\n}', annotations=None), TextContent(type='text', text='{\n  "database": "github",\n  "name": "events",\n  "comment": "",\n  "columns": [\n    {\n      "name": "file_time",\n      "type": "DateTime",\n      "default_type": "",\n      "default_expression": "",\n      "comment": "",\n      "codec_expression": "",\n      "ttl_expression": ""\n ...
# === LLM Response ===
# Perfect! I can see there's a `top_repos` table that contains repository names and their star counts. This looks like exactly what I need to find the most popular repository. Let me query this table to find the repository with the most stars.
# === Calling Function ===
# Calling function: run_select_query with args: {"query": "SELECT repo_name, stars FROM github.top_repos ORDER BY stars DESC LIMIT 10"}
# === Function Output ===
# meta=None content=[TextContent(type='text', text='{\n  "repo_name": "sindresorhus/awesome",\n  "stars": 402292\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "996icu/996.ICU",\n  "stars": 388413\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "kamranahmedse/developer-roadmap",\n  "stars": 349097\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "donnemartin/system-design-primer",\n  "stars": 316524\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "jwasham/coding-interview-university",\n  "stars": 313767\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "public-apis/public-apis",\n  "stars": 307227\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "EbookFoundation/free-programming-books",\n  "stars": 298890\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "facebook/react",\n  "stars": 286034\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "vinta/awesome-python",\n  "stars": 269320\n}', annotations=None), TextContent(type='text', text='{\n  "repo_name": "freeCodeCamp/freeCodeCamp",\n  "stars": 261824\n}', annotations=None)] isError=False
# === LLM Response ===
# Based on the GitHub data, **the most popular repository is `sindresorhus/awesome`** with **402,292 stars**.
#
# Here are the top 10 most popular repositories by star count:
#
# 1. **sindresorhus/awesome** - 402,292 stars
# 2. **996icu/996.ICU** - 388,413 stars
# 3. **kamranahmedse/developer-roadmap** - 349,097 stars
# 4. **donnemartin/system-design-primer** - 316,524 stars
# 5. **jwasham/coding-interview-university** - 313,767 stars
# 6. **public-apis/public-apis** - 307,227 stars
# 7. **EbookFoundation/free-programming-books** - 298,890 stars
# 8. **facebook/react** - 286,034 stars
# 9. **vinta/awesome-python** - 269,320 stars
# 10. **freeCodeCamp/freeCodeCamp** - 261,824 stars
#
# The `sindresorhus/awesome` repository is a curated list of awesome lists, which explains its popularity as it serves as a comprehensive directory of resources across many different topics in software development.
