# %% [markdown]
# # How to build an AI Agent with LlamaIndex and ClickHouse MCP Server
#
# In this notebook we'll see how to build a [LlamaIndex](https://github.com/run-llama/llama_index)  AI agent that can interact with [ClickHouse's SQL playground](https://sql.clickhouse.com/).
#
# Updated dependencies: 5 September 2026. Outputs are cleared; see [setup and validation](../README.md).

# %% [markdown]
# ## Install libraries
# We need to install LlamaIndex, the ClickHouse connector library, and Anthropic, as we'll be using that as our LLM.

# %%
# %pip install -r requirements.txt

# %%
# Dependencies installed above.

# %% [markdown]
# ## Setup credentials
# Let's provide our Anthropic API key.

# %%
import getpass
import os

# %%
key_name = "OPENAI_API_KEY" if os.getenv("LLM_PROVIDER", "anthropic") == "openai" else "ANTHROPIC_API_KEY"
if not os.getenv(key_name):
    os.environ[key_name] = getpass.getpass(f"Enter {key_name}: ")

# %% [markdown]
# ## Initialize LLM
# And then initialize the Claude Sonnet 4.0 model.

# %%
from llama_index.llms.anthropic import Anthropic

# %%
from llama_index.llms.openai import OpenAI
if os.getenv("LLM_PROVIDER", "anthropic") == "openai":
    llm = OpenAI(model=os.getenv("OPENAI_MODEL", "gpt-5.6-luna"), max_tokens=1024, api_base=os.getenv("OPENAI_BASE_URL", "https://api.openai.com/v1"))
else:
    llm = Anthropic(temperature=1, max_tokens=4096, model=os.getenv("ANTHROPIC_MODEL", "claude-sonnet-5"))

# %% [markdown]
# ## Configure MCP client
# Next, we're going to create an MCP client that connects to the ClickHouse SQL Playground via the  ClickHouse MCP server.

# %% [markdown]
# We then need to convert those from Python functions into Llama Index tools:

# %%
from llama_index.tools.mcp import BasicMCPClient, McpToolSpec

# %%
import os
mcp_client = BasicMCPClient(
    "uv", 
    args=["tool", "run", "--python", "3.13", "--from", "mcp-clickhouse==0.6.0", "mcp-clickhouse"],
    env={
        "CLICKHOUSE_HOST": os.getenv("CLICKHOUSE_HOST", 'sql-clickhouse.clickhouse.com'),
        "CLICKHOUSE_PORT": os.getenv("CLICKHOUSE_PORT", '8443'),
        "CLICKHOUSE_USER": os.getenv("CLICKHOUSE_USER", 'demo'),
        "CLICKHOUSE_PASSWORD": os.getenv("CLICKHOUSE_PASSWORD", ''),
        "CLICKHOUSE_SECURE": os.getenv("CLICKHOUSE_SECURE", 'true')
    } 
)

mcp_tool_spec = McpToolSpec(
    client=mcp_client,
)

# %%
tools = await mcp_tool_spec.to_tool_list_async()

# %% [markdown]
# ## Creating Agent
# Now we're ready to create an agent that has access to those tools. We're going to set the maximum number of tool calls in one run to 10, but you can modify that if you want.

# %%
from llama_index.core.agent.workflow import FunctionAgent

# %%
agent = FunctionAgent(tools=tools, llm=llm, timeout=120)

# %% [markdown]
# ## Running the agent
# Finally, we can ask the agent a question:

# %%
response = await agent.run(user_msg=os.getenv("MCP_PROMPT", "What's the most popular repository?"))
print(response)
